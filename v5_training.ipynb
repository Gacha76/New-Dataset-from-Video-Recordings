# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
model_v5n = torch.hub.load('ultralytics/yolov5','yolov5n')
model_v5n
# Out:
# Using cache found in C:\Users\tshar/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-1-21 Python-3.11.6 torch-2.1.1+cpu CPU
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# Adding AutoShape...
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 16, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
# ...

# %%
class_names = ['Traffic Signal', 'Lamp Post', 'Zebra Crossing', 'Bike', 'Car', 'Rikshaw', 'Tyre Works', 'Tree', 'Tractor', 'Cattle', 'Vegetation', 'Electricity Pole', 'Building', 'Board', 'Wall', 'person', 'Bus', 'Bridge', 'Road Divider', 'Tempo', 'Traffic Sign Board', 'Flag', 'Crane', 'Cycle', 'Dog', 'Truck', 'Overbridge', 'Manhole', 'Bus Stop', 'Barricade', 'Petrol Pump', 'Ambulance', 'Goat', 'Cart']
class_names
# Out:
# ['Traffic Signal',
#  'Lamp Post',
#  'Zebra Crossing',
#  'Bike',
#  'Car',
#  'Rikshaw',
#  'Tyre Works',
#  'Tree',
#  'Tractor',
#  'Cattle',
#  'Vegetation',
#  'Electricity Pole',
#  'Building',
#  'Board',
#  'Wall',
#  'person',
#  'Bus',
#  'Bridge',
#  'Road Divider',
#  'Tempo',
#  'Traffic Sign Board',
#  'Flag',
#  'Crane',
#  'Cycle',
#  'Dog',
#  'Truck',
#  'Overbridge',
#  'Manhole',
#  'Bus Stop',
#  'Barricade',
#  'Petrol Pump',
#  'Ambulance',
#  'Goat',
#  'Cart']

# %%
# Run labelImg in anaconda powershell prompt

# %%
# Run 'cd "C:/My files/Notes/Sem-7/Mini 2" && python yolov5/train.py --img 640 --batch 16 --epochs 50 --data yolov5/dataset.yaml --weights yolov5n.pt --workers 0'

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 50 --data yolov5/dataset.yaml --weights yolov5n.pt --workers 0
# Out:
# ^C
